# %% [markdown]
# # 高分辨率语义分割LUCC数据集
#
# ## 1）GID 童心仪
# 分辨率：0.8米
# 波段数：4
# 波段顺序：NirRGB
# 类别：
# -建筑：建筑
# -植被：农田，森林 草地
# -水：水
#
# ## 2）GAGO 佳格比赛
# 分辨率：高分辨率，亚米级
# 波段数：3（可合成一个近红外）
# 类别：
# 建筑：建筑-180
# 植被：植被-60
# 水体：水体-240
# 道路：道路-120
# 其他：其他-0
#
#
# ## 3）dstl kaggle比赛
# 分辨率：1.24米
# 波段数：8（提取其中4个波段）
# 类别：
# 建筑： Buildings，Misc. Manmade structures
# 道路： Road，Track
# 植被:  Trees，Crops
# 水: Waterway，Standing water
# 车辆：Vehicle Large，Vehicle Small
#
# ## 4）Slovenia 2019 分割
# 分辨率：10m
# 波段数：>4
# 类别：
# 植被：农田，草地，森林，灌木
# 水：水体
# 湿地：  湿地
# 人造：  人造
# 裸地：  裸地
# 冻：冻原
#
#
# # 高分辨率地物分类LUCC数据集
#
#
# ## 1）DeepSat4 kaggle数据集
# 分辨率：1米
# 波段数：4
# 类别：
# 裸土：裸土
# 植被：树木，草地
# 其他：其他
#
# ## 2）DeepSat6 kaggle数据集
# 分辨率：1米
# 波段数：4
# 类别：
# 裸土：裸土
# 植被：树木，草地
# 道路：道路
# 建筑物：建筑物
# 水体：水体
# ## 3）eurosat 数据集
# 分辨率：10米
# 波段数：>4
# 类别：
# 裸土：
# 植被：AnnualCrop,Forest, Herbaceous vegetation, Pasture, PermanentCrop
# 道路：Highway
# 建筑物：Industrial,Residential
# 水体：River,SeaLake

# %% [markdown]
# # 数据集可视化

# %%
# CCF GAGO影像和mask可视化

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

im = mpimg.imread(r'F:\田德宇5st\2020——三室自研\固体废弃物\相关工作\gago\BDCI\BDCI\0_data\CCF-training\data\1.png')
mask = mpimg.imread(r'F:\田德宇5st\2020——三室自研\固体废弃物\相关工作\gago\BDCI\BDCI\0_data\CCF-training\mask_bmp\1.bmp')

fig = plt.figure(figsize=(21,12))
ax = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(im)
ax.set_title('img')
plt.colorbar(orientation='horizontal')
ax = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow(mask, cmap='gist_ncar')
ax.set_title('mask')
plt.colorbar(orientation='horizontal')
# imgplot = plt.imshow(img)
# plt.colorbar()
# plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x,y):
    return (x+y)*np.exp(-5.0*(x**2+y**2))

x,y = np.mgrid[-1:1:100j, -1:1:100j]

z = f(x,y)

plt.imshow(z,origin='lower')
plt.colorbar()

i,j = np.unravel_index(z.argmin(), z.shape)

plt.scatter(i,j,color='b')

plt.xlim(0,100)
plt.ylim(0,100)
plt.title('Draw a point on an image with matplotlib (2/2)')

plt.savefig("draw_on_image_01.png")
plt.show()
plt.close()
